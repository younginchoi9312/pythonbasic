# %%
# !pip install pillow
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\youngin choi\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\youngin choi\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\youngin choi\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\youngin choi\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\youngin choi\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\youngin choi\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
import matplotlib.pyplot as plt   # 그림관련
import matplotlib.image as mpimg  # 사진관련


# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "pCQCx31jPRnzjcI1kZ3v"
client_secret = "ERgLg7cnQo"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈 / 사진크기 2m이하
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 251,
#             "height": 201
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "배그린",
#                 "confidence": 0.01
#             }
#         }
#     ]
# }

# %%
# 얼굴 인식, 나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "pCQCx31jPRnzjcI1kZ3v"
client_secret = "ERgLg7cnQo"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈 / 사진크기 2m이하
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 275,
#             "height": 183
#         },
#         "faceCount": 3
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 28,
#                 "width": 16,
#                 "height": 16
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.868865
#             },
#             "age": {
#                 "value": "58~62",
#                 "confidence": 0.155399
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.544263
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.807216
#             }
#         },
#         {
#             "roi": {
#                 "x": 94,
#                 "y": 80,
#                 "width": 15,
#                 "height": 15
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.537094
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.156983
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.665639
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.771907
#             }
#         },
#         {
#             "roi": {
#                 "x": 143,
#                 "y": 35,
#                 "width": 17,
#                 "height": 17
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999788
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 0.856071
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999587
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.513575
#             }
#         }
#     ]
# }

# %% [markdown]
# #기본 문법 학습

# %%
# dict형과 json에 대해

dict = {'Name':'pinkwink','Age':'None','class':['beginner','blog']}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('ee','nothing')
# Out:
# 'nothing'

# %%
# Json (Java Script Object Notation)

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-21','log':True},
        {'date':'2019-03-22','log':False},
    ]
    
    
    
    
}

# %%
import json
json_test = json.dumps(customer, indent=4, ensure_ascii=False)
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-21",
#             "log": true
#         },
#         {
#             "date": "2019-03-22",
#             "log": false
#         }
#     ]
# }

# %%
import json   # json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 275,
#             "height": 183
#         },
#         "faceCount": 3
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 28,
#                 "width": 16,
#                 "height": 16
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.868865
#             },
#             "age": {
#                 "value": "58~62",
#                 "confidence": 0.155399
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.544263
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.807216
#             }
#         },
#         {
#             "roi": {
#                 "x": 94,
#                 "y": 80,
#                 "width": 15,
#                 "height": 15
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.537094
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.156983
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.665639
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.771907
#             }
#         },
#         {
#             "roi": {
#                 "x": 143,
#                 "y": 35,
#                 "width": 17,
#                 "height": 17
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999788
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 0.856071
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999587
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.513575
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(response)
# Out:
# <Response [200]>

# %%
parsed['faces']
# Out:
# [{'roi': {'x': 173, 'y': 28, 'width': 16, 'height': 16},
#   'landmark': None,
#   'gender': {'value': 'female', 'confidence': 0.868865},
#   'age': {'value': '58~62', 'confidence': 0.155399},
#   'emotion': {'value': 'smile', 'confidence': 0.544263},
#   'pose': {'value': 'part_face', 'confidence': 0.807216}},
#  {'roi': {'x': 94, 'y': 80, 'width': 15, 'height': 15},
#   'landmark': None,
#   'gender': {'value': 'female', 'confidence': 0.537094},
#   'age': {'value': '30~34', 'confidence': 0.156983},
#   'emotion': {'value': 'smile', 'confidence': 0.665639},
#   'pose': {'value': 'false_face', 'confidence': 0.771907}},
#  {'roi': {'x': 143, 'y': 35, 'width': 17, 'height': 17},
#   'landmark': None,
#   'gender': {'value': 'female', 'confidence': 0.999788},
#   'age': {'value': '21~25', 'confidence': 0.856071},
#   'emotion': {'value': 'neutral', 'confidence': 0.999587},
#   'pose': {'value': 'false_face', 'confidence': 0.513575}}]

# %%
parsed['faces'][0]['roi']
# Out:
# {'x': 173, 'y': 28, 'width': 16, 'height': 16}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'female', 'confidence': 0.868865}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'smile', 'confidence': 0.544263}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " ; " + str(age_confi)

# %%
print(annotation)
# Out:
# female : 0.868865
# smile : 0.544263
# 58~62 ; 0.155399

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap=True, fontsize = 17, color ='white')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "pCQCx31jPRnzjcI1kZ3v"
client_secret = "ERgLg7cnQo"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %matplotlib inline

# %%
import json   # json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 275,
#             "height": 183
#         },
#         "faceCount": 3
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 28,
#                 "width": 16,
#                 "height": 16
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.868865
#             },
#             "age": {
#                 "value": "58~62",
#                 "confidence": 0.155399
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.544263
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.807216
#             }
#         },
#         {
#             "roi": {
#                 "x": 94,
#                 "y": 80,
#                 "width": 15,
#                 "height": 15
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.537094
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.156983
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.665639
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.771907
#             }
#         },
#         {
#             "roi": {
#                 "x": 143,
#                 "y": 35,
#                 "width": 17,
#                 "height": 17
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999788
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 0.856071
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999587
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.513575
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)



for each in parsed['faces']:
    x,y,w,h = each ['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)    
    
    
    annotation = gender + " : " + str(round(gen_confi*100,2)) + "%" + '\n' + emotion + " : " + str(round(emo_confi*100,2)) + "%" + '\n' + age + " ; " + str(round(age_confi*100,2)) +"%" + '\n'
    
    plt.text(x-30,y-30, annotation, wrap=True, fontsize = 15, color ='black')
    
    
    
    
plt.show()
